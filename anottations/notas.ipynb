# %%
feat      → adiciona nova funcionalidade
fix       → corrige bug/erro
refactor  → reorganiza código sem mudar funcionalidade
docs      → altera documentação
style     → altera aparência/formatação visual
chore     → manutenção/configuração interna do projeto

# %% [markdown]
# pdf = pymupdf
# IA/resumo = transformers torch
# Interface = pyside6
#
# libs: pymupdf pyside6 ollama
#
#
# 1- Primeiro serviço(PDF service):
#
# vai estar localizado em services
#
# abre PDF
# percorre páginas
# extrai texto
# retorna tudo
#
# 2- Criação da interface gráfica:
#
# abre explorador de arquivos
# usuário escolhe PDF
# chama extract_text
# mostra resultado na tela
#
# 2.1 Implementando IA local
#
# Ollama é uma ferramenta que permite rodar modelos de IA generativa localmente no seu computador, sem depender da nuvem.
# Ele funciona como um “gerenciador de LLMs”.
# Com ele você consegue baixar e executar modelos como:
#
# Llama
# Mistral
# DeepSeek
# Gemma
#
# O por que da escolha:
#
# gerencia modelos automaticamente
# cria uma API local pronta
# funciona offline

# %%
próximas features incríveis
EXTRAÇÃO INTELIGENTE

Encontrar:

datas
valores
nomes
artigos
CHAT COM PDF

Perguntar:

“Quem é o réu?”

EXPORTAR RESUMO

Salvar:

TXT
PDF
DOCX
OCR

Ler PDFs escaneados.

HISTÓRICO

Salvar análises anteriores.

# %%
3- Extração de dados:

filtrar datas, valores, cpf, artigos,email 

vou usar o padrao regex ( padrao de busca em texto)

# %% [markdown]
# 18/05

# %% [markdown]
# - Otimizaçao da IA , redução do texto gerado pelo processo ( alteracoes feita no ai_services)
#
# implementaçao do  QThread. ( Software esta travando ao gerar o resumo com a IA)
#
# Porque:
#
# resolve congelamento
# deixa profissional
# melhora UX absurdamente
